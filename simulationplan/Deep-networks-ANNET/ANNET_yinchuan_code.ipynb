# %%
"""
@author: yinchuan li
@version: 2020.03.12
Change to complex-valued network
Off-grid LISTA net - Only the training data changed to off-grid data
Learning W1 and W2
A CNN is added: x = f(W1,W2,x) + CNN(x)
"""
import numpy as np
import torch
import torch.nn as nn
import matplotlib.pyplot as plt
# import torch.nn.functional as F
# from torch.utils.data import Dataset, DataLoader
import os
import time


def soft_comp(x, threshold):
    mask1 = x > threshold
    mask2 = x < -threshold
    out = torch.zeros_like(x)
    out += mask1.float() * -threshold + mask1.float() * x
    out += mask2.float() * threshold + mask2.float() * x
    return out


class LISTA(nn.Module):
    def __init__(self, _w1_, _w2_, C, stage, alpha, thr, useGPU):
        super(LISTA, self).__init__()
        self.alpha = alpha
        self.stage = stage
        self._flat_weights_names = []
        self._all_weights = []
        self.n = _w2_.shape[0]

        if (useGPU):
            self.C_real = (nn.Parameter(torch.from_numpy(C.real))).cuda()
            self.C_imag = (nn.Parameter(torch.from_numpy(C.imag))).cuda()
        else:
            self.C_real = nn.Parameter(torch.from_numpy(C.real))
            self.C_imag = nn.Parameter(torch.from_numpy(C.imag))

        for layer in range(stage):

            conv1d_1 = nn.Conv1d(1, 2, 4, padding=1)   #
            # # 加上一层relu
            conv1d_2 = nn.Conv1d(2, 1, 2, padding=1)   # output channel is one

            conv1d_1 = conv1d_1.double()
            conv1d_2 = conv1d_2.double()

            w_real = nn.Parameter(torch.from_numpy(_w2_.real))
            w_imag = nn.Parameter(torch.from_numpy(_w2_.imag))
            b_real = nn.Parameter(torch.from_numpy(_w1_.real))
            b_imag = nn.Parameter(torch.from_numpy(_w1_.imag))

            th = nn.Parameter(torch.tensor(thr))

            if (useGPU):
                conv1d_1 = conv1d_1.cuda()
                conv1d_2 = conv1d_2.cuda()
                w_real = w_real.cuda()
                w_imag = w_imag.cuda()
                b_real = b_real.cuda()
                b_imag = b_imag.cuda()
                th = th.cuda()

            layer_params = (w_real, w_imag, b_real, b_imag, th, conv1d_1, conv1d_2)
            suffix = ''
            param_names = ['weights_real_{}{}', 'weights_imag_{}{}',
                           'bias_real_{}{}', 'bias_imag_{}{}', 'threshold{}{}', 'conv1d_1_{}{}', 'conv1d_2_{}{}']
            param_names = [x.format(layer, suffix) for x in param_names]
            for name, param in zip(param_names, layer_params):
                setattr(self, name, param)
            self._flat_weights_names.extend(param_names)
            self._all_weights.append(param_names)


    def forward(self, y_real, y_imag):
        self.bs = y_real.shape[-1]
        '''
                # param_names = ['weights_real_{}{}', 'weights_imag_{}{}',
                #                'bias_real_{}{}', 'bias_imag_{}{}', 'threshold{}{}']
                # w2_real, w2_imag, w1_real, w1_imag, threshold
        '''

        x_real = torch.zeros([self.n, self.bs],dtype=torch.float64)
        x_imag = torch.zeros([self.n, self.bs],dtype=torch.float64)

        if (y_real.is_cuda):
            x_real = x_real.cuda()
            x_imag = x_imag.cuda()

        # from the first layer to the last layer, where in the first layer x=0
        for layer in range(self.stage):
            param_names = self._all_weights[layer][:]

            z_org_real = getattr(self, param_names[0]).mm(x_real) - \
                         getattr(self, param_names[1]).mm(x_imag) + \
                         getattr(self, param_names[2]).mm(y_real) - \
                         getattr(self, param_names[3]).mm(y_imag)

            z_org_imag = getattr(self, param_names[0]).mm(x_imag) + \
                         getattr(self, param_names[1]).mm(x_real) + \
                         getattr(self, param_names[2]).mm(y_imag) + \
                         getattr(self, param_names[3]).mm(y_real)

            conv1d_1 = getattr(self, param_names[5])
            conv1d_2 = getattr(self, param_names[6])

            # x_cnn_real = (conv1d_1(x_real.T.view(self.bs, 1, self.n))).view(self.bs, self.n).T
            # x_cnn_imag = (conv1d_1(x_imag.T.view(self.bs, 1, self.n))).view(self.bs, self.n).T
            x_cnn_real = (conv1d_2(conv1d_1(x_real.T.view(self.bs, 1, self.n)))).view(self.bs, self.n).T
            x_cnn_imag = (conv1d_2(conv1d_1(x_imag.T.view(self.bs, 1, self.n)))).view(self.bs, self.n).T

            x_real = soft_comp(z_org_real, getattr(self, param_names[4])) + x_cnn_real
            x_imag = soft_comp(z_org_imag, getattr(self, param_names[4])) + x_cnn_imag

        Cx_real = self.C_real.mm(x_real) - self.C_imag.mm(x_imag)
        Cx_imag = self.C_imag.mm(x_real) + self.C_real.mm(x_imag)
        return Cx_real, Cx_imag, x_real, x_imag


def my_loss_y(A_real, A_imag, x_real, x_imag, y_real, y_imag):
    criterion1 = nn.MSELoss()
    # criterion2 = L1Loss_comp
    y_h_real = torch.mm(A_real, x_real) - torch.mm(A_imag, x_imag)
    y_h_imag = torch.mm(A_imag, x_real) + torch.mm(A_real, x_imag)
    # compute the losss
    loss1 = criterion1(y_h_real, y_real) + criterion1(y_h_imag, y_imag)
    # loss2 = 0.1 * _lambda * criterion2(y_h_real, y_h_imag, y_real, y_imag)
    return loss1


def my_loss_nmse(x_real, x_imag, x_gt_real, x_gt_imag):
    x_real[x_real < 1e-8] = 2e-8
    x_imag[x_real < 1e-8] = 2e-8
    x_gt_real[x_gt_real < 1e-8] = 1e-8
    x_gt_imag[x_gt_imag < 1e-8] = 1e-8
    x_nmse = 0
    for i in range(x_real.shape[1]):
        x_gt_norm = torch.sum(x_gt_real[:, i] ** 2 + x_gt_imag[:, i] ** 2)
        sub_norm = torch.sum((x_real[:, i] - x_gt_real[:, i]) ** 2 + (x_imag[:, i] - x_gt_imag[:, i]) ** 2)
        x_nmse += sub_norm / x_gt_norm
    return x_nmse / x_real.shape[1]


def my_loss_x(x_real, x_imag, x_gt_real, x_gt_imag):
    criterion1 = nn.MSELoss()
    plot_flag = 0

    # compute the losss
    loss1 = (criterion1(x_real, x_gt_real)  # *(x_gt_real.shape[0]*x_gt_real.shape[1])/ non_zero_real
             + criterion1(x_imag, x_gt_imag))  # *(x_gt_imag.shape[0]*x_gt_imag.shape[1])/ non_zero_imag


    if plot_flag:
        xi = x_imag.detach().numpy()[:, 0]
        xr = x_real.detach().numpy()[:, 0]
        xi_gt = x_gt_imag.detach().numpy()[:, 0]
        xr_gt = x_gt_real.detach().numpy()[:, 0]
        plt.figure()
        plt.subplot(311)
        plt.stem(range(xi.shape[0]), xi, use_line_collection=True, markerfmt='D', label='LISTA')
        plt.stem(range(xi_gt.shape[0]), xi_gt, use_line_collection=True, markerfmt='o', label='Ground_truth')
        plt.legend(loc='upper left', bbox_to_anchor=(0.2, 0.95))
        plt.title("LISTA-Net Real Part")

        plt.subplot(312)
        plt.stem(range(xr.shape[0]), xr, markerfmt='D', label='LISTA')
        plt.stem(range(xr_gt.shape[0]), xr_gt, use_line_collection=True, markerfmt='o', label='Ground_truth')
        plt.legend(loc='best', bbox_to_anchor=(0.2, 0.95))
        plt.title("LISTA-Net Imag Part")

        plt.subplot(313)
        plt.stem(range(xi.shape[0]), np.sqrt(xi ** 2 + xr ** 2), use_line_collection=True, markerfmt='D', label='LISTA')
        plt.stem(range(xi_gt.shape[0]), np.sqrt(xi_gt ** 2 + xr_gt ** 2), use_line_collection=True, markerfmt='o',
                 label='Ground_truth')
        plt.legend(loc='best', bbox_to_anchor=(0.2, 0.95))
        plt.title("LISTA-Net Imag Part")
        plt.show()

    return loss1


def L1Loss_comp(input_real, input_imag, target_real, target_imag):
    return torch.mean(torch.sqrt((input_real - target_real) ** 2 + (input_imag - target_imag) ** 2))



def now_to_date(format_string="%Y-%m-%d-%H-%M-%S"):
    time_stamp = int(time.time())
    time_array = time.localtime(time_stamp)
    str_date = time.strftime(format_string, time_array)
    return str_date


def save_my_data(y_train, x_train, y_valid, x_valid, path_data='data/LISTA_Train_Valid_Data/'):
    print('===> Saving data...')
    str_date = now_to_date()
    data = {
        'train_data': y_train,
        'train_label': x_train,
        'valid_data': y_valid,
        'valid_label': x_valid}
    if not os.path.isdir(path_data):
        os.makedirs(path_data)
    torch.save(data, path_data + 'data-' + str_date + '.pt')
    print('===> Saving data finished...')


def save_my_model(net, optimizer, epochs, loss_list, loss_val_list, learning_rate, stage,
                  path_checkpoint='model/LISTA-Update-Weights/checkpoint/'):
    print('===> Saving models...')
    str_date = now_to_date()
    state = {
        'epoch': epochs,
        'model_state_dict': net.state_dict(),
        'optimizer_state_dict': optimizer.state_dict(),
        'loss': loss_list,
        'loss_val': loss_val_list,
        'learning_rate': learning_rate,
        'stage': stage
    }
    # path_checkpoint = 'model/LISTA-Updata-Weights/checkpoint/'
    if not os.path.isdir(path_checkpoint):
        os.makedirs(path_checkpoint)
    torch.save(state, path_checkpoint + 'LISTA_net-' + str_date + '.pt')
    print('===> Saving model finished...')


def my_lista(A, C, Phi, y_train, x_train, y_valid, x_valid, _lambda, alpha, bs, epochs,stage, learning_rate):
    useGPU = 1
    nt = y_train.shape[-1]
    nv = y_valid.shape[-1]

    # batch_size = y_train.shape[-1]

    _w2_ = (np.eye(A.shape[-1]) - (1 / alpha) * np.matmul(A.conj().T, A))  # note that here is the conjugate transpose
    _w1_ = ((1 / alpha) * A.conj().T)
    # map
    # convert the data into tensors
    C_real = torch.from_numpy(C.real)
    C_imag = torch.from_numpy(C.imag)
    y_real = torch.from_numpy(y_train.real)
    y_imag = torch.from_numpy(y_train.imag)
    y_gt_real = torch.from_numpy(x_train.real)
    y_gt_imag = torch.from_numpy(x_train.imag)
    yt_real = torch.from_numpy(y_valid.real)
    yt_imag = torch.from_numpy(y_valid.imag)
    yt_gt_real = torch.from_numpy(x_valid.real)
    yt_gt_imag = torch.from_numpy(x_valid.imag)

    if (useGPU):
        y_real = y_real.cuda()
        y_imag = y_imag.cuda()
        y_gt_real = y_gt_real.cuda()
        y_gt_imag = y_gt_imag.cuda()
        yt_real = yt_real.cuda()
        yt_imag = yt_imag.cuda()
        yt_gt_real = yt_gt_real.cuda()
        yt_gt_imag = yt_gt_imag.cuda()

    # list of losses at every epoch
    loss_list = []
    loss_val_list = []
    # ------- Training phase --------------
    # number of layers:
    # stage = 10
    net = LISTA(_w1_, _w2_, C, stage, alpha=alpha, thr=_lambda / alpha, useGPU=useGPU)

    # learning_rate = 0.01
    # optimizer = torch.optim.SGD(net.parameters(), lr=learning_rate, momentum=0.9)
    # optimizer = torch.optim.Adam(net.parameters(), lr=learning_rate) # momentum=0.9
    # optimizer = torch.optim.RMSprop(net.parameters(), lr=learning_rate, momentum=0.9) # momentum=0.9
    # optimizer = torch.optim.SGD(net.parameters(), lr=learning_rate, momentum=0.9) #

    for epoch in range(epochs):

        # if epoch < 100:
        #     learning_rate = 1e-3
        # elif epoch < 200:
        #     learning_rate = 1e-4
        # else:
        #     learning_rate = 1e-6

        optimizer = torch.optim.Adam(net.parameters(), lr=learning_rate) # momentum=0.9

        for i in range((nt - 1) // bs + 1):
            # get the outputs
            start_i = i * bs
            end_i = start_i + bs
            ye_real, ye_imag, x_real, x_imag = net(y_real[:, start_i:end_i], y_imag[:, start_i:end_i])
            if(useGPU):
                ye_real = ye_real.cuda()
                ye_imag = ye_imag.cuda()
                x_real = x_real.cuda()
                x_imag = x_imag.cuda()

            loss = my_loss_x(ye_real, ye_imag, y_gt_real[:, start_i:end_i], y_gt_imag[:, start_i:end_i])

            loss.backward()
            optimizer.step()
            optimizer.zero_grad()
            if i % 200 == 0:
                print('Epoch: %d mini-batch: %d  train-loss: %.5f ' % (epoch, i + 1, loss.detach().data))
            loss_list.append(loss.detach().data)
        with torch.no_grad():
            for i in range((nv - 1) // (2 * bs) + 1):
                start_i = i * (2 * bs)
                end_i = start_i + (2 * bs)
                y_pred_real, y_pred_imag, x_pred_real, x_pred_imag = net(yt_real[:, start_i:end_i], yt_imag[:, start_i:end_i])

                loss_val = my_loss_x(y_pred_real, y_pred_imag,
                                        yt_gt_real[:, start_i:end_i], yt_gt_imag[:, start_i:end_i])
                # if i % 10 == 0:
                #     print('Epoch: %d mini-batch: %d  valid-loss %.2f'%(epoch, i, loss_val.detach().data))
                loss_val_list.append(loss_val.detach().data)

            # print('Epoch: %d  mean-valid-loss %.5f' % (epoch, np.mean(print_valid_loss)))
            print('Epoch: %d  mean-valid-loss %.5f' % (epoch, np.mean([x.item() for x in loss_val_list])))


    save_my_model(net, optimizer, epochs, loss_list, loss_val_list, learning_rate, stage,
                  path_checkpoint='model/LISTA-Update-Weights/checkpoint/')
    # save_my_data(y_train, x_train, y_valid, x_valid, path_data='data/LISTA_Train_Valid_Data/')
    real_pred, imag_pred = [], []
    with torch.no_grad():
        for i in range((nv - 1) // (2 * bs) + 1):
            start_i = i * (2 * bs)
            end_i = start_i + (2 * bs)
            real, imag, _, _ = net.forward(yt_real[:, start_i:end_i], yt_imag[:, start_i:end_i])
            real_pred.append(real)
            imag_pred.append(imag)
    real_pred = torch.cat(real_pred, dim=1)
    imag_pred = torch.cat(imag_pred, dim=1)
    print(my_loss_nmse(real_pred, imag_pred, yt_gt_real, yt_gt_imag),"++++++++++++++++++++++++++++++++")
    # print(my_loss_nmse(net.ret[layer]['real'],  net.ret[layer]['imag'], yt_gt_real, yt_gt_imag).detach().cpu().numpy())
    if (useGPU):
        y_pred_real = y_pred_real.cpu()
        y_pred_imag = y_pred_imag.cpu()
        x_pred_real = x_pred_real.cpu()
        x_pred_imag = x_pred_imag.cpu()

    return y_pred_real.numpy(), y_pred_imag.numpy(), x_pred_real.numpy(), x_pred_imag.numpy(), loss_list

# %%
#!/usr/bin/env python3
# -*- coding: utf-8 -*-
"""
@author: yinchuan li
@version: 2020.03.12
Change to complex-valued network
Off-grid LISTA net
Change the loss to y-loss
where in the network return x, and in the loss we use y-Cx
"""

import numpy as np
import matplotlib.pyplot as plt
# from LISTA_E import my_lista
import random as rd
import torch
from scipy.special import comb, perm
batch_size = 2048
learning_rate = 1e-3
stage = 6
# dimensions of the sparse signal x
n = 8
# dimension of the compressed signal y
m = 4
# sparsity : non-zero values over n
sparsity = 2

# training and testing number:
train_number = 5000000
valid_number = 1000
# number of training iterations (epochs)
numIter = 50

# w state of randomness
# rng = np.random.RandomState(23)

# create the 1:N sample
sample = np.array(list(range(m))).reshape(m, 1)
# create the frequency grid
f_grid = 1/n*np.array(list(range(n))).reshape(1, n)

# generate the dictionary, without the sampling matrix Phi
# C = np.exp(1j*2*np.pi*np.matmul(sample, f_grid))
# A = C.copy()

# generate the dictionary with the sampling matrix Phi
C = np.exp(1j*2*np.pi*np.matmul(sample, f_grid))
phi = np.zeros([m])
p = 0.5 # sparsity level
Ns = int(np.floor((p)*m)) # the sampling number, note that should be int
index = rd.sample(range(m),Ns)
phi[index] = 1
Phi = np.diag(phi)
A = np.matmul(Phi,C)


# generate off-grid training/testing data
def generate_off_grid_data(m, n, Phi, sparsity, bs, SNR=20):
    w_real = np.zeros([sparsity, bs])
    w_imag = np.zeros([sparsity, bs])
    Y_star = np.zeros((m, bs)) + 1j * np.zeros((m, bs))
    Y = np.zeros((m, bs)) + 1j * np.zeros((m, bs))
    w_star = np.zeros([sparsity, bs]) + 1j * np.zeros([sparsity, bs])
    distance = 2/(n-1)
    f_interval = np.arange(0,sparsity*distance,distance)

    for i in range(bs):
        # f_star = (1-(sparsity-1)*distance) * np.sort(np.random.random((sparsity))) + f_interval
        f_star = np.sort(np.random.random((sparsity)))
        f_star = f_star.reshape(1,sparsity)
        Cf = np.exp(1j * 2 * np.pi * np.matmul(sample, f_star))

        w_real[:, i] = np.ones(sparsity)
        w_imag[:, i] = np.ones(sparsity)
        # w_real[:, i] = 2*np.random.random((sparsity))-1
        # w_imag[:, i] = 2*np.random.random((sparsity))-1
        w_star[:, i] = w_real[:, i] + 1j * w_imag[:, i]
        Y_star[:, i]  = np.matmul(Cf,w_star[:, i])
        Y[:, i] = np.matmul(Phi,Y_star[:, i])

    return Y, Y_star, f_star, w_star

train_input, train_output, f_star, w_star = generate_off_grid_data(m, n, Phi, sparsity, train_number)
valid_input, valid_output, f_star, w_star = generate_off_grid_data(m, n, Phi, sparsity, valid_number)

# print(y_train[:,1])
# print(x_train[:,1])

# compute the max eigen value of the w'*w
# alpha = np.linalg.norm(A,ord=2) ** 2
alpha = 5
# regularization paramter
_lambda = 0.5

SNR_list = []

Y_pred_real, Y_pred_imag, X_pred_real, X_pred_imag, err_list = my_lista(A, C, Phi, train_input, train_output, valid_input, valid_output,
                                               _lambda, alpha, bs=batch_size, epochs=numIter, stage = stage, learning_rate = learning_rate)
Y_pred_lista = Y_pred_real + 1j*Y_pred_imag


wt_gt_real = torch.from_numpy(w_star.real)
wt_gt_imag = torch.from_numpy(w_star.imag)

yt_gt_real = torch.from_numpy(valid_output.real)
yt_gt_imag = torch.from_numpy(valid_output.imag)

y_valid_input_real = torch.from_numpy(valid_input.real)
y_valid_input_imag = torch.from_numpy(valid_input.imag)


f_grid_plt = f_grid.reshape(n)
f_star_plt = f_star.reshape(sparsity)
for i in range(10):
    plt.figure()
    plt.subplot(211)
    plt.plot(f_grid_plt, X_pred_real[:, i], color='red', linestyle='--', marker='*', linewidth=1.5,
             label='LISTA')
    plt.legend(loc='upper left', bbox_to_anchor=(0.2, 0.95))

    plt.stem(f_star_plt, wt_gt_real.detach().numpy()[:, i], linefmt='b-', markerfmt='bo')

    plt.title("X Real Part")

    plt.subplot(212)
    plt.plot(f_grid_plt, X_pred_imag[:, i], color='red', linestyle='--', marker='*', linewidth=1.5,
             label='LISTA')
    plt.legend(loc='best', bbox_to_anchor=(0.2, 0.95))
    plt.stem(f_star_plt, wt_gt_imag.detach().numpy()[:, i], linefmt='b-', markerfmt='bo')

    plt.title("X Imag Part")
    plt.show()

    plt.figure()
    plt.subplot(211)
    plt.plot(Y_pred_real[:, i], color='red', linestyle='--', marker='*', linewidth=1.5,
             label='LISTA')
    plt.plot(yt_gt_real.detach().numpy()[:, i], color='green', linestyle='-', marker='+', linewidth=1.5,
             label='Ground_truth')
    plt.plot(y_valid_input_real.detach().numpy()[:, i], color='black', linestyle='-', marker='+', linewidth=1.5,
             label='input')
    plt.legend(loc='upper left', bbox_to_anchor=(0.2, 0.95))
    plt.title("Y Real Part")

    plt.subplot(212)
    plt.plot(Y_pred_imag[:, i], color='red', linestyle='--', marker='*', linewidth=1.5,
             label='LISTA')
    plt.plot(yt_gt_imag.detach().numpy()[:, i], color='green', linestyle='-', marker='+', linewidth=1.5,
             label='Ground_truth')
    plt.plot(y_valid_input_imag.detach().numpy()[:, i], color='black', linestyle='-', marker='+', linewidth=1.5,
             label='input')
    plt.legend(loc='best', bbox_to_anchor=(0.2, 0.95))
    plt.title("Y Imag Part")
    plt.show()
# Out:
# Epoch: 0 mini-batch: 1  train-loss: 3.71787
# Epoch: 0 mini-batch: 201  train-loss: 2.07587
# Epoch: 0 mini-batch: 401  train-loss: 2.02019
# Epoch: 0 mini-batch: 601  train-loss: 2.02713
# Epoch: 0 mini-batch: 801  train-loss: 2.00362
# Epoch: 0 mini-batch: 1001  train-loss: 1.97328
# Epoch: 0 mini-batch: 1201  train-loss: 2.01844
# Epoch: 0 mini-batch: 1401  train-loss: 1.99672
# Epoch: 0 mini-batch: 1601  train-loss: 2.01258
# Epoch: 0 mini-batch: 1801  train-loss: 2.03266
# Epoch: 0 mini-batch: 2001  train-loss: 2.02098
# Epoch: 0 mini-batch: 2201  train-loss: 2.01070
# Epoch: 0 mini-batch: 2401  train-loss: 1.97052
# Epoch: 0  mean-valid-loss 1.94069
# Epoch: 1 mini-batch: 1  train-loss: 2.02124
# Epoch: 1 mini-batch: 201  train-loss: 2.03723
# Epoch: 1 mini-batch: 401  train-loss: 2.00182
# Epoch: 1 mini-batch: 601  train-loss: 2.01524
# Epoch: 1 mini-batch: 801  train-loss: 1.99648
# Epoch: 1 mini-batch: 1001  train-loss: 1.96627
# Epoch: 1 mini-batch: 1201  train-loss: 2.01174
# Epoch: 1 mini-batch: 1401  train-loss: 1.99145
# Epoch: 1 mini-batch: 1601  train-loss: 2.00980
# Epoch: 1 mini-batch: 1801  train-loss: 2.03203
# Epoch: 1 mini-batch: 2001  train-loss: 2.01994
# Epoch: 1 mini-batch: 2201  train-loss: 2.00726
# Epoch: 1 mini-batch: 2401  train-loss: 1.96727
# Epoch: 1  mean-valid-loss 1.94065
# Epoch: 2 mini-batch: 1  train-loss: 2.01855
# Epoch: 2 mini-batch: 201  train-loss: 2.03582
# Epoch: 2 mini-batch: 401  train-loss: 2.00080
# Epoch: 2 mini-batch: 601  train-loss: 2.01347
# Epoch: 2 mini-batch: 801  train-loss: 1.99585
# Epoch: 2 mini-batch: 1001  train-loss: 1.96667
# Epoch: 2 mini-batch: 1201  train-loss: 2.01184
# Epoch: 2 mini-batch: 1401  train-loss: 1.99088
# Epoch: 2 mini-batch: 1601  train-loss: 2.00929
# Epoch: 2 mini-batch: 1801  train-loss: 2.03215
# Epoch: 2 mini-batch: 2001  train-loss: 2.01913
# Epoch: 2 mini-batch: 2201  train-loss: 2.00672
# Epoch: 2 mini-batch: 2401  train-loss: 1.96690
# Epoch: 2  mean-valid-loss 1.94056
# Epoch: 3 mini-batch: 1  train-loss: 2.01807
# Epoch: 3 mini-batch: 201  train-loss: 2.03578
# Epoch: 3 mini-batch: 401  train-loss: 2.00091
# Epoch: 3 mini-batch: 601  train-loss: 2.01315
# Epoch: 3 mini-batch: 801  train-loss: 1.99588
# Epoch: 3 mini-batch: 1001  train-loss: 1.96647
# Epoch: 3 mini-batch: 1201  train-loss: 2.01171
# Epoch: 3 mini-batch: 1401  train-loss: 1.99066
# Epoch: 3 mini-batch: 1601  train-loss: 2.00907
# Epoch: 3 mini-batch: 1801  train-loss: 2.03218
# Epoch: 3 mini-batch: 2001  train-loss: 2.01893
# Epoch: 3 mini-batch: 2201  train-loss: 2.00628
# Epoch: 3 mini-batch: 2401  train-loss: 1.96671
# Epoch: 3  mean-valid-loss 1.94052
# Epoch: 4 mini-batch: 1  train-loss: 2.01790
# Epoch: 4 mini-batch: 201  train-loss: 2.03572
# Epoch: 4 mini-batch: 401  train-loss: 2.00071
# Epoch: 4 mini-batch: 601  train-loss: 2.01308
# Epoch: 4 mini-batch: 801  train-loss: 1.99589
# Epoch: 4 mini-batch: 1001  train-loss: 1.96611
# Epoch: 4 mini-batch: 1201  train-loss: 2.01163
# Epoch: 4 mini-batch: 1401  train-loss: 1.99061
# Epoch: 4 mini-batch: 1601  train-loss: 2.00888
# Epoch: 4 mini-batch: 1801  train-loss: 2.03214
# Epoch: 4 mini-batch: 2001  train-loss: 2.01895
# Epoch: 4 mini-batch: 2201  train-loss: 2.00606
# Epoch: 4 mini-batch: 2401  train-loss: 1.96679
# Epoch: 4  mean-valid-loss 1.94049
# Epoch: 5 mini-batch: 1  train-loss: 2.01777
# Epoch: 5 mini-batch: 201  train-loss: 2.03552
# Epoch: 5 mini-batch: 401  train-loss: 2.00061
# Epoch: 5 mini-batch: 601  train-loss: 2.01306
# Epoch: 5 mini-batch: 801  train-loss: 1.99591
# Epoch: 5 mini-batch: 1001  train-loss: 1.96579
# Epoch: 5 mini-batch: 1201  train-loss: 2.01147
# Epoch: 5 mini-batch: 1401  train-loss: 1.99046
# Epoch: 5 mini-batch: 1601  train-loss: 2.00887
# Epoch: 5 mini-batch: 1801  train-loss: 2.03209
# Epoch: 5 mini-batch: 2001  train-loss: 2.01904
# Epoch: 5 mini-batch: 2201  train-loss: 2.00603
# Epoch: 5 mini-batch: 2401  train-loss: 1.96683
# Epoch: 5  mean-valid-loss 1.94048
# Epoch: 6 mini-batch: 1  train-loss: 2.01784
# Epoch: 6 mini-batch: 201  train-loss: 2.03541
# Epoch: 6 mini-batch: 401  train-loss: 2.00045
# Epoch: 6 mini-batch: 601  train-loss: 2.01294
# Epoch: 6 mini-batch: 801  train-loss: 1.99587
# Epoch: 6 mini-batch: 1001  train-loss: 1.96570
# Epoch: 6 mini-batch: 1201  train-loss: 2.01133
# Epoch: 6 mini-batch: 1401  train-loss: 1.99039
# Epoch: 6 mini-batch: 1601  train-loss: 2.00880
# Epoch: 6 mini-batch: 1801  train-loss: 2.03195
# Epoch: 6 mini-batch: 2001  train-loss: 2.01904
# Epoch: 6 mini-batch: 2201  train-loss: 2.00611
# Epoch: 6 mini-batch: 2401  train-loss: 1.96677
# Epoch: 6  mean-valid-loss 1.94050
# Epoch: 7 mini-batch: 1  train-loss: 2.01778
# Epoch: 7 mini-batch: 201  train-loss: 2.03531
# Epoch: 7 mini-batch: 401  train-loss: 2.00043
# Epoch: 7 mini-batch: 601  train-loss: 2.01321
# Epoch: 7 mini-batch: 801  train-loss: 1.99595
# Epoch: 7 mini-batch: 1001  train-loss: 1.96563
# Epoch: 7 mini-batch: 1201  train-loss: 2.01138
# Epoch: 7 mini-batch: 1401  train-loss: 1.99040
# Epoch: 7 mini-batch: 1601  train-loss: 2.00872
# Epoch: 7 mini-batch: 1801  train-loss: 2.03181
# Epoch: 7 mini-batch: 2001  train-loss: 2.01904
# Epoch: 7 mini-batch: 2201  train-loss: 2.00614
# Epoch: 7 mini-batch: 2401  train-loss: 1.96670
# Epoch: 7  mean-valid-loss 1.94052
# Epoch: 8 mini-batch: 1  train-loss: 2.01782
# Epoch: 8 mini-batch: 201  train-loss: 2.03537
# Epoch: 8 mini-batch: 401  train-loss: 2.00045
# Epoch: 8 mini-batch: 601  train-loss: 2.01316
# Epoch: 8 mini-batch: 801  train-loss: 1.99588
# Epoch: 8 mini-batch: 1001  train-loss: 1.96562
# Epoch: 8 mini-batch: 1201  train-loss: 2.01143
# Epoch: 8 mini-batch: 1401  train-loss: 1.99044
# Epoch: 8 mini-batch: 1601  train-loss: 2.00863
# Epoch: 8 mini-batch: 1801  train-loss: 2.03186
# Epoch: 8 mini-batch: 2001  train-loss: 2.01913
# Epoch: 8 mini-batch: 2201  train-loss: 2.00621
# Epoch: 8 mini-batch: 2401  train-loss: 1.96654
# Epoch: 8  mean-valid-loss 1.94053
# Epoch: 9 mini-batch: 1  train-loss: 2.01766
# Epoch: 9 mini-batch: 201  train-loss: 2.03520
# Epoch: 9 mini-batch: 401  train-loss: 2.00052
# Epoch: 9 mini-batch: 601  train-loss: 2.01330
# Epoch: 9 mini-batch: 801  train-loss: 1.99586
# Epoch: 9 mini-batch: 1001  train-loss: 1.96566
# Epoch: 9 mini-batch: 1201  train-loss: 2.01145
# Epoch: 9 mini-batch: 1401  train-loss: 1.99039
# Epoch: 9 mini-batch: 1601  train-loss: 2.00848
# Epoch: 9 mini-batch: 1801  train-loss: 2.03169
# Epoch: 9 mini-batch: 2001  train-loss: 2.01916
# Epoch: 9 mini-batch: 2201  train-loss: 2.00634
# Epoch: 9 mini-batch: 2401  train-loss: 1.96669
# Epoch: 9  mean-valid-loss 1.94054
# Epoch: 10 mini-batch: 1  train-loss: 2.01766
# Epoch: 10 mini-batch: 201  train-loss: 2.03519
# Epoch: 10 mini-batch: 401  train-loss: 2.00052
# Epoch: 10 mini-batch: 601  train-loss: 2.01301
# Epoch: 10 mini-batch: 801  train-loss: 1.99589
# Epoch: 10 mini-batch: 1001  train-loss: 1.96571
# Epoch: 10 mini-batch: 1201  train-loss: 2.01146
# Epoch: 10 mini-batch: 1401  train-loss: 1.99046
# Epoch: 10 mini-batch: 1601  train-loss: 2.00853
# Epoch: 10 mini-batch: 1801  train-loss: 2.03166
# Epoch: 10 mini-batch: 2001  train-loss: 2.01918
# Epoch: 10 mini-batch: 2201  train-loss: 2.00608
# Epoch: 10 mini-batch: 2401  train-loss: 1.96668
# Epoch: 10  mean-valid-loss 1.94054
# Epoch: 11 mini-batch: 1  train-loss: 2.01775
# Epoch: 11 mini-batch: 201  train-loss: 2.03507
# Epoch: 11 mini-batch: 401  train-loss: 2.00046
# Epoch: 11 mini-batch: 601  train-loss: 2.01362
# Epoch: 11 mini-batch: 801  train-loss: 1.99594
# Epoch: 11 mini-batch: 1001  train-loss: 1.96561
# Epoch: 11 mini-batch: 1201  train-loss: 2.01151
# Epoch: 11 mini-batch: 1401  train-loss: 1.99047
# Epoch: 11 mini-batch: 1601  train-loss: 2.00841
# Epoch: 11 mini-batch: 1801  train-loss: 2.03167
# Epoch: 11 mini-batch: 2001  train-loss: 2.01921
# Epoch: 11 mini-batch: 2201  train-loss: 2.00607
# Epoch: 11 mini-batch: 2401  train-loss: 1.96663
# Epoch: 11  mean-valid-loss 1.94055
# Epoch: 12 mini-batch: 1  train-loss: 2.01771
# Epoch: 12 mini-batch: 201  train-loss: 2.03509
# Epoch: 12 mini-batch: 401  train-loss: 2.00045
# Epoch: 12 mini-batch: 601  train-loss: 2.01357
# Epoch: 12 mini-batch: 801  train-loss: 1.99592
# Epoch: 12 mini-batch: 1001  train-loss: 1.96560
# Epoch: 12 mini-batch: 1201  train-loss: 2.01156
# Epoch: 12 mini-batch: 1401  train-loss: 1.99051
# Epoch: 12 mini-batch: 1601  train-loss: 2.00842
# Epoch: 12 mini-batch: 1801  train-loss: 2.03169
# Epoch: 12 mini-batch: 2001  train-loss: 2.01925
# Epoch: 12 mini-batch: 2201  train-loss: 2.00602
# Epoch: 12 mini-batch: 2401  train-loss: 1.96664
# Epoch: 12  mean-valid-loss 1.94055
# Epoch: 13 mini-batch: 1  train-loss: 2.01768
# Epoch: 13 mini-batch: 201  train-loss: 2.03523
# Epoch: 13 mini-batch: 401  train-loss: 2.00058
# Epoch: 13 mini-batch: 601  train-loss: 2.01364
# Epoch: 13 mini-batch: 801  train-loss: 1.99595
# Epoch: 13 mini-batch: 1001  train-loss: 1.96562
# Epoch: 13 mini-batch: 1201  train-loss: 2.01158
# Epoch: 13 mini-batch: 1401  train-loss: 1.99052
# Epoch: 13 mini-batch: 1601  train-loss: 2.00843
# Epoch: 13 mini-batch: 1801  train-loss: 2.03169
# Epoch: 13 mini-batch: 2001  train-loss: 2.01924
# Epoch: 13 mini-batch: 2201  train-loss: 2.00621
# Epoch: 13 mini-batch: 2401  train-loss: 1.96672
# Epoch: 13  mean-valid-loss 1.94055
# Epoch: 14 mini-batch: 1  train-loss: 2.01757
# Epoch: 14 mini-batch: 201  train-loss: 2.03508
# Epoch: 14 mini-batch: 401  train-loss: 2.00054
# Epoch: 14 mini-batch: 601  train-loss: 2.01362
# Epoch: 14 mini-batch: 801  train-loss: 1.99595
# Epoch: 14 mini-batch: 1001  train-loss: 1.96555
# Epoch: 14 mini-batch: 1201  train-loss: 2.01163
# Epoch: 14 mini-batch: 1401  train-loss: 1.99055
# Epoch: 14 mini-batch: 1601  train-loss: 2.00837
# Epoch: 14 mini-batch: 1801  train-loss: 2.03165
# Epoch: 14 mini-batch: 2001  train-loss: 2.01930
# Epoch: 14 mini-batch: 2201  train-loss: 2.00607
# Epoch: 14 mini-batch: 2401  train-loss: 1.96665
# Epoch: 14  mean-valid-loss 1.94054
# Epoch: 15 mini-batch: 1  train-loss: 2.01757
# Epoch: 15 mini-batch: 201  train-loss: 2.03516
# Epoch: 15 mini-batch: 401  train-loss: 2.00054
# Epoch: 15 mini-batch: 601  train-loss: 2.01361
# Epoch: 15 mini-batch: 801  train-loss: 1.99593
# Epoch: 15 mini-batch: 1001  train-loss: 1.96549
# Epoch: 15 mini-batch: 1201  train-loss: 2.01155
# Epoch: 15 mini-batch: 1401  train-loss: 1.99059
# Epoch: 15 mini-batch: 1601  train-loss: 2.00832
# Epoch: 15 mini-batch: 1801  train-loss: 2.03169
# Epoch: 15 mini-batch: 2001  train-loss: 2.01921
# Epoch: 15 mini-batch: 2201  train-loss: 2.00596
# Epoch: 15 mini-batch: 2401  train-loss: 1.96685
# Epoch: 15  mean-valid-loss 1.94055
# Epoch: 16 mini-batch: 1  train-loss: 2.01774
# Epoch: 16 mini-batch: 201  train-loss: 2.03497
# Epoch: 16 mini-batch: 401  train-loss: 2.00044
# Epoch: 16 mini-batch: 601  train-loss: 2.01352
# Epoch: 16 mini-batch: 801  train-loss: 1.99588
# Epoch: 16 mini-batch: 1001  train-loss: 1.96546
# Epoch: 16 mini-batch: 1201  train-loss: 2.01164
# Epoch: 16 mini-batch: 1401  train-loss: 1.99067
# Epoch: 16 mini-batch: 1601  train-loss: 2.00856
# Epoch: 16 mini-batch: 1801  train-loss: 2.03158
# Epoch: 16 mini-batch: 2001  train-loss: 2.01935
# Epoch: 16 mini-batch: 2201  train-loss: 2.00610
# Epoch: 16 mini-batch: 2401  train-loss: 1.96693
# Epoch: 16  mean-valid-loss 1.94055
# Epoch: 17 mini-batch: 1  train-loss: 2.01768
# Epoch: 17 mini-batch: 201  train-loss: 2.03498
# Epoch: 17 mini-batch: 401  train-loss: 2.00036
# Epoch: 17 mini-batch: 601  train-loss: 2.01324
# Epoch: 17 mini-batch: 801  train-loss: 1.99571
# Epoch: 17 mini-batch: 1001  train-loss: 1.96542
# Epoch: 17 mini-batch: 1201  train-loss: 2.01175
# Epoch: 17 mini-batch: 1401  train-loss: 1.99072
# Epoch: 17 mini-batch: 1601  train-loss: 2.00861
# Epoch: 17 mini-batch: 1801  train-loss: 2.03183
# Epoch: 17 mini-batch: 2001  train-loss: 2.01934
# Epoch: 17 mini-batch: 2201  train-loss: 2.00616
# Epoch: 17 mini-batch: 2401  train-loss: 1.96693
# Epoch: 17  mean-valid-loss 1.94056
# Epoch: 18 mini-batch: 1  train-loss: 2.01772
# Epoch: 18 mini-batch: 201  train-loss: 2.03498
# Epoch: 18 mini-batch: 401  train-loss: 2.00021
# Epoch: 18 mini-batch: 601  train-loss: 2.01286
# Epoch: 18 mini-batch: 801  train-loss: 1.99552
# Epoch: 18 mini-batch: 1001  train-loss: 1.96541
# Epoch: 18 mini-batch: 1201  train-loss: 2.01163
# Epoch: 18 mini-batch: 1401  train-loss: 1.99073
# Epoch: 18 mini-batch: 1601  train-loss: 2.00838
# Epoch: 18 mini-batch: 1801  train-loss: 2.03175
# Epoch: 18 mini-batch: 2001  train-loss: 2.01933
# Epoch: 18 mini-batch: 2201  train-loss: 2.00623
# Epoch: 18 mini-batch: 2401  train-loss: 1.96709
# Epoch: 18  mean-valid-loss 1.94058
# Epoch: 19 mini-batch: 1  train-loss: 2.01775
# Epoch: 19 mini-batch: 201  train-loss: 2.03487
# Epoch: 19 mini-batch: 401  train-loss: 2.00021
# Epoch: 19 mini-batch: 601  train-loss: 2.01286
# Epoch: 19 mini-batch: 801  train-loss: 1.99549
# Epoch: 19 mini-batch: 1001  train-loss: 1.96551
# Epoch: 19 mini-batch: 1201  train-loss: 2.01159
# Epoch: 19 mini-batch: 1401  train-loss: 1.99073
# Epoch: 19 mini-batch: 1601  train-loss: 2.00859
# Epoch: 19 mini-batch: 1801  train-loss: 2.03150
# Epoch: 19 mini-batch: 2001  train-loss: 2.01931
# Epoch: 19 mini-batch: 2201  train-loss: 2.00601
# Epoch: 19 mini-batch: 2401  train-loss: 1.96690
# Epoch: 19  mean-valid-loss 1.94057
# Epoch: 20 mini-batch: 1  train-loss: 2.01764
# Epoch: 20 mini-batch: 201  train-loss: 2.03494
# Epoch: 20 mini-batch: 401  train-loss: 2.00032
# Epoch: 20 mini-batch: 601  train-loss: 2.01292
# Epoch: 20 mini-batch: 801  train-loss: 1.99562
# Epoch: 20 mini-batch: 1001  train-loss: 1.96550
# Epoch: 20 mini-batch: 1201  train-loss: 2.01165
# Epoch: 20 mini-batch: 1401  train-loss: 1.99072
# Epoch: 20 mini-batch: 1601  train-loss: 2.00861
# Epoch: 20 mini-batch: 1801  train-loss: 2.03144
# Epoch: 20 mini-batch: 2001  train-loss: 2.01929
# Epoch: 20 mini-batch: 2201  train-loss: 2.00610
# Epoch: 20 mini-batch: 2401  train-loss: 1.96693
# Epoch: 20  mean-valid-loss 1.94058
# Epoch: 21 mini-batch: 1  train-loss: 2.01774
# Epoch: 21 mini-batch: 201  train-loss: 2.03490
# Epoch: 21 mini-batch: 401  train-loss: 2.00024
# Epoch: 21 mini-batch: 601  train-loss: 2.01287
# Epoch: 21 mini-batch: 801  train-loss: 1.99547
# Epoch: 21 mini-batch: 1001  train-loss: 1.96537
# Epoch: 21 mini-batch: 1201  train-loss: 2.01161
# Epoch: 21 mini-batch: 1401  train-loss: 1.99070
# Epoch: 21 mini-batch: 1601  train-loss: 2.00859
# Epoch: 21 mini-batch: 1801  train-loss: 2.03151
# Epoch: 21 mini-batch: 2001  train-loss: 2.01919
# Epoch: 21 mini-batch: 2201  train-loss: 2.00619
# Epoch: 21 mini-batch: 2401  train-loss: 1.96696
# Epoch: 21  mean-valid-loss 1.94057
# Epoch: 22 mini-batch: 1  train-loss: 2.01761
# Epoch: 22 mini-batch: 201  train-loss: 2.03494
# Epoch: 22 mini-batch: 401  train-loss: 2.00032
# Epoch: 22 mini-batch: 601  train-loss: 2.01292
# Epoch: 22 mini-batch: 801  train-loss: 1.99549
# Epoch: 22 mini-batch: 1001  train-loss: 1.96560
# Epoch: 22 mini-batch: 1201  train-loss: 2.01151
# Epoch: 22 mini-batch: 1401  train-loss: 1.99069
# Epoch: 22 mini-batch: 1601  train-loss: 2.00859
# Epoch: 22 mini-batch: 1801  train-loss: 2.03158
# Epoch: 22 mini-batch: 2001  train-loss: 2.01922
# Epoch: 22 mini-batch: 2201  train-loss: 2.00619
# Epoch: 22 mini-batch: 2401  train-loss: 1.96697
# Epoch: 22  mean-valid-loss 1.94057
# Epoch: 23 mini-batch: 1  train-loss: 2.01762
# Epoch: 23 mini-batch: 201  train-loss: 2.03491
# Epoch: 23 mini-batch: 401  train-loss: 2.00019
# Epoch: 23 mini-batch: 601  train-loss: 2.01291
# Epoch: 23 mini-batch: 801  train-loss: 1.99549
# Epoch: 23 mini-batch: 1001  train-loss: 1.96551
# Epoch: 23 mini-batch: 1201  train-loss: 2.01149
# Epoch: 23 mini-batch: 1401  train-loss: 1.99067
# Epoch: 23 mini-batch: 1601  train-loss: 2.00860
# Epoch: 23 mini-batch: 1801  train-loss: 2.03151
# Epoch: 23 mini-batch: 2001  train-loss: 2.01921
# Epoch: 23 mini-batch: 2201  train-loss: 2.00619
# Epoch: 23 mini-batch: 2401  train-loss: 1.96699
# Epoch: 23  mean-valid-loss 1.94056
# Epoch: 24 mini-batch: 1  train-loss: 2.01762
# Epoch: 24 mini-batch: 201  train-loss: 2.03491
# Epoch: 24 mini-batch: 401  train-loss: 2.00029
# Epoch: 24 mini-batch: 601  train-loss: 2.01288
# Epoch: 24 mini-batch: 801  train-loss: 1.99546
# Epoch: 24 mini-batch: 1001  train-loss: 1.96546
# Epoch: 24 mini-batch: 1201  train-loss: 2.01162
# Epoch: 24 mini-batch: 1401  train-loss: 1.99066
# Epoch: 24 mini-batch: 1601  train-loss: 2.00848
# Epoch: 24 mini-batch: 1801  train-loss: 2.03169
# Epoch: 24 mini-batch: 2001  train-loss: 2.01919
# Epoch: 24 mini-batch: 2201  train-loss: 2.00625
# Epoch: 24 mini-batch: 2401  train-loss: 1.96703
# Epoch: 24  mean-valid-loss 1.94056
# Epoch: 25 mini-batch: 1  train-loss: 2.01772
# Epoch: 25 mini-batch: 201  train-loss: 2.03495
# Epoch: 25 mini-batch: 401  train-loss: 2.00020
# Epoch: 25 mini-batch: 601  train-loss: 2.01288
# Epoch: 25 mini-batch: 801  train-loss: 1.99545
# Epoch: 25 mini-batch: 1001  train-loss: 1.96545
# Epoch: 25 mini-batch: 1201  train-loss: 2.01163
# Epoch: 25 mini-batch: 1401  train-loss: 1.99064
# Epoch: 25 mini-batch: 1601  train-loss: 2.00836
# Epoch: 25 mini-batch: 1801  train-loss: 2.03168
# Epoch: 25 mini-batch: 2001  train-loss: 2.01922
# Epoch: 25 mini-batch: 2201  train-loss: 2.00631
# Epoch: 25 mini-batch: 2401  train-loss: 1.96708
# Epoch: 25  mean-valid-loss 1.94056
# Epoch: 26 mini-batch: 1  train-loss: 2.01772
# Epoch: 26 mini-batch: 201  train-loss: 2.03492
# Epoch: 26 mini-batch: 401  train-loss: 2.00025
# Epoch: 26 mini-batch: 601  train-loss: 2.01287
# Epoch: 26 mini-batch: 801  train-loss: 1.99542
# Epoch: 26 mini-batch: 1001  train-loss: 1.96552
# Epoch: 26 mini-batch: 1201  train-loss: 2.01151
# Epoch: 26 mini-batch: 1401  train-loss: 1.99067
# Epoch: 26 mini-batch: 1601  train-loss: 2.00860
# Epoch: 26 mini-batch: 1801  train-loss: 2.03137
# Epoch: 26 mini-batch: 2001  train-loss: 2.01915
# Epoch: 26 mini-batch: 2201  train-loss: 2.00628
# Epoch: 26 mini-batch: 2401  train-loss: 1.96705
# Epoch: 26  mean-valid-loss 1.94056
# Epoch: 27 mini-batch: 1  train-loss: 2.01771
# Epoch: 27 mini-batch: 201  train-loss: 2.03487
# Epoch: 27 mini-batch: 401  train-loss: 2.00016
# Epoch: 27 mini-batch: 601  train-loss: 2.01288
# Epoch: 27 mini-batch: 801  train-loss: 1.99544
# Epoch: 27 mini-batch: 1001  train-loss: 1.96547
# Epoch: 27 mini-batch: 1201  train-loss: 2.01150
# Epoch: 27 mini-batch: 1401  train-loss: 1.99067
# Epoch: 27 mini-batch: 1601  train-loss: 2.00862
# Epoch: 27 mini-batch: 1801  train-loss: 2.03147
# Epoch: 27 mini-batch: 2001  train-loss: 2.01919
# Epoch: 27 mini-batch: 2201  train-loss: 2.00630
# Epoch: 27 mini-batch: 2401  train-loss: 1.96708
# Epoch: 27  mean-valid-loss 1.94056
# Epoch: 28 mini-batch: 1  train-loss: 2.01770
# Epoch: 28 mini-batch: 201  train-loss: 2.03487
# Epoch: 28 mini-batch: 401  train-loss: 2.00026
# Epoch: 28 mini-batch: 601  train-loss: 2.01284
# Epoch: 28 mini-batch: 801  train-loss: 1.99540
# Epoch: 28 mini-batch: 1001  train-loss: 1.96557
# Epoch: 28 mini-batch: 1201  train-loss: 2.01151
# Epoch: 28 mini-batch: 1401  train-loss: 1.99064
# Epoch: 28 mini-batch: 1601  train-loss: 2.00861
# Epoch: 28 mini-batch: 1801  train-loss: 2.03150
# Epoch: 28 mini-batch: 2001  train-loss: 2.01905
# Epoch: 28 mini-batch: 2201  train-loss: 2.00623
# Epoch: 28 mini-batch: 2401  train-loss: 1.96700
# Epoch: 28  mean-valid-loss 1.94056
# Epoch: 29 mini-batch: 1  train-loss: 2.01770
# Epoch: 29 mini-batch: 201  train-loss: 2.03484
# Epoch: 29 mini-batch: 401  train-loss: 2.00034
# Epoch: 29 mini-batch: 601  train-loss: 2.01282
# Epoch: 29 mini-batch: 801  train-loss: 1.99541
# Epoch: 29 mini-batch: 1001  train-loss: 1.96550
# Epoch: 29 mini-batch: 1201  train-loss: 2.01153
# Epoch: 29 mini-batch: 1401  train-loss: 1.99065
# Epoch: 29 mini-batch: 1601  train-loss: 2.00860
# Epoch: 29 mini-batch: 1801  train-loss: 2.03144
# Epoch: 29 mini-batch: 2001  train-loss: 2.01912
# Epoch: 29 mini-batch: 2201  train-loss: 2.00623
# Epoch: 29 mini-batch: 2401  train-loss: 1.96709
# Epoch: 29  mean-valid-loss 1.94056
# Epoch: 30 mini-batch: 1  train-loss: 2.01771
# Epoch: 30 mini-batch: 201  train-loss: 2.03490
# Epoch: 30 mini-batch: 401  train-loss: 2.00019
# Epoch: 30 mini-batch: 601  train-loss: 2.01280
# Epoch: 30 mini-batch: 801  train-loss: 1.99543
# Epoch: 30 mini-batch: 1001  train-loss: 1.96545
# Epoch: 30 mini-batch: 1201  train-loss: 2.01149
# Epoch: 30 mini-batch: 1401  train-loss: 1.99074
# Epoch: 30 mini-batch: 1601  train-loss: 2.00861
# Epoch: 30 mini-batch: 1801  train-loss: 2.03167
# Epoch: 30 mini-batch: 2001  train-loss: 2.01922
# Epoch: 30 mini-batch: 2201  train-loss: 2.00624
# Epoch: 30 mini-batch: 2401  train-loss: 1.96706
# Epoch: 30  mean-valid-loss 1.94056
# Epoch: 31 mini-batch: 1  train-loss: 2.01773
# Epoch: 31 mini-batch: 201  train-loss: 2.03486
# Epoch: 31 mini-batch: 401  train-loss: 2.00021
# Epoch: 31 mini-batch: 601  train-loss: 2.01276
# Epoch: 31 mini-batch: 801  train-loss: 1.99543
# Epoch: 31 mini-batch: 1001  train-loss: 1.96549
# Epoch: 31 mini-batch: 1201  train-loss: 2.01147
# Epoch: 31 mini-batch: 1401  train-loss: 1.99073
# Epoch: 31 mini-batch: 1601  train-loss: 2.00860
# Epoch: 31 mini-batch: 1801  train-loss: 2.03148
# Epoch: 31 mini-batch: 2001  train-loss: 2.01905
# Epoch: 31 mini-batch: 2201  train-loss: 2.00624
# Epoch: 31 mini-batch: 2401  train-loss: 1.96701
# Epoch: 31  mean-valid-loss 1.94056
# Epoch: 32 mini-batch: 1  train-loss: 2.01771
# Epoch: 32 mini-batch: 201  train-loss: 2.03486
# Epoch: 32 mini-batch: 401  train-loss: 2.00034
# Epoch: 32 mini-batch: 601  train-loss: 2.01281
# Epoch: 32 mini-batch: 801  train-loss: 1.99540
# Epoch: 32 mini-batch: 1001  train-loss: 1.96541
# Epoch: 32 mini-batch: 1201  train-loss: 2.01147
# Epoch: 32 mini-batch: 1401  train-loss: 1.99072
# Epoch: 32 mini-batch: 1601  train-loss: 2.00859
# Epoch: 32 mini-batch: 1801  train-loss: 2.03162
# Epoch: 32 mini-batch: 2001  train-loss: 2.01910
# Epoch: 32 mini-batch: 2201  train-loss: 2.00622
# Epoch: 32 mini-batch: 2401  train-loss: 1.96702
# Epoch: 32  mean-valid-loss 1.94056
# Epoch: 33 mini-batch: 1  train-loss: 2.01771
# Epoch: 33 mini-batch: 201  train-loss: 2.03484
# Epoch: 33 mini-batch: 401  train-loss: 2.00025
# Epoch: 33 mini-batch: 601  train-loss: 2.01280
# Epoch: 33 mini-batch: 801  train-loss: 1.99545
# Epoch: 33 mini-batch: 1001  train-loss: 1.96544
# Epoch: 33 mini-batch: 1201  train-loss: 2.01157
# Epoch: 33 mini-batch: 1401  train-loss: 1.99065
# Epoch: 33 mini-batch: 1601  train-loss: 2.00857
# Epoch: 33 mini-batch: 1801  train-loss: 2.03144
# Epoch: 33 mini-batch: 2001  train-loss: 2.01902
# Epoch: 33 mini-batch: 2201  train-loss: 2.00627
# Epoch: 33 mini-batch: 2401  train-loss: 1.96703
# Epoch: 33  mean-valid-loss 1.94056
# Epoch: 34 mini-batch: 1  train-loss: 2.01766
# Epoch: 34 mini-batch: 201  train-loss: 2.03481
# Epoch: 34 mini-batch: 401  train-loss: 2.00028
# Epoch: 34 mini-batch: 601  train-loss: 2.01283
# Epoch: 34 mini-batch: 801  train-loss: 1.99548
# Epoch: 34 mini-batch: 1001  train-loss: 1.96551
# Epoch: 34 mini-batch: 1201  train-loss: 2.01148
# Epoch: 34 mini-batch: 1401  train-loss: 1.99071
# Epoch: 34 mini-batch: 1601  train-loss: 2.00861
# Epoch: 34 mini-batch: 1801  train-loss: 2.03153
# Epoch: 34 mini-batch: 2001  train-loss: 2.01917
# Epoch: 34 mini-batch: 2201  train-loss: 2.00625
# Epoch: 34 mini-batch: 2401  train-loss: 1.96706
# Epoch: 34  mean-valid-loss 1.94055
# Epoch: 35 mini-batch: 1  train-loss: 2.01764
# Epoch: 35 mini-batch: 201  train-loss: 2.03484
# Epoch: 35 mini-batch: 401  train-loss: 2.00017
# Epoch: 35 mini-batch: 601  train-loss: 2.01273
# Epoch: 35 mini-batch: 801  train-loss: 1.99542
# Epoch: 35 mini-batch: 1001  train-loss: 1.96542
# Epoch: 35 mini-batch: 1201  train-loss: 2.01149
# Epoch: 35 mini-batch: 1401  train-loss: 1.99071
# Epoch: 35 mini-batch: 1601  train-loss: 2.00861
# Epoch: 35 mini-batch: 1801  train-loss: 2.03149
# Epoch: 35 mini-batch: 2001  train-loss: 2.01907
# Epoch: 35 mini-batch: 2201  train-loss: 2.00628
# Epoch: 35 mini-batch: 2401  train-loss: 1.96703
# Epoch: 35  mean-valid-loss 1.94055
# Epoch: 36 mini-batch: 1  train-loss: 2.01773
# Epoch: 36 mini-batch: 201  train-loss: 2.03482
# Epoch: 36 mini-batch: 401  train-loss: 2.00029
# Epoch: 36 mini-batch: 601  train-loss: 2.01278
# Epoch: 36 mini-batch: 801  train-loss: 1.99559
# Epoch: 36 mini-batch: 1001  train-loss: 1.96541
# Epoch: 36 mini-batch: 1201  train-loss: 2.01152
# Epoch: 36 mini-batch: 1401  train-loss: 1.99065
# Epoch: 36 mini-batch: 1601  train-loss: 2.00860
# Epoch: 36 mini-batch: 1801  train-loss: 2.03151
# Epoch: 36 mini-batch: 2001  train-loss: 2.01901
# Epoch: 36 mini-batch: 2201  train-loss: 2.00631
# Epoch: 36 mini-batch: 2401  train-loss: 1.96704
# Epoch: 36  mean-valid-loss 1.94055
# Epoch: 37 mini-batch: 1  train-loss: 2.01768
# Epoch: 37 mini-batch: 201  train-loss: 2.03478
# Epoch: 37 mini-batch: 401  train-loss: 2.00021
# Epoch: 37 mini-batch: 601  train-loss: 2.01276
# Epoch: 37 mini-batch: 801  train-loss: 1.99543
# Epoch: 37 mini-batch: 1001  train-loss: 1.96547
# Epoch: 37 mini-batch: 1201  train-loss: 2.01151
# Epoch: 37 mini-batch: 1401  train-loss: 1.99074
# Epoch: 37 mini-batch: 1601  train-loss: 2.00856
# Epoch: 37 mini-batch: 1801  train-loss: 2.03152
# Epoch: 37 mini-batch: 2001  train-loss: 2.01915
# Epoch: 37 mini-batch: 2201  train-loss: 2.00630
# Epoch: 37 mini-batch: 2401  train-loss: 1.96706
# Epoch: 37  mean-valid-loss 1.94055
# Epoch: 38 mini-batch: 1  train-loss: 2.01771
# Epoch: 38 mini-batch: 201  train-loss: 2.03482
# Epoch: 38 mini-batch: 401  train-loss: 2.00023
# Epoch: 38 mini-batch: 601  train-loss: 2.01268
# Epoch: 38 mini-batch: 801  train-loss: 1.99539
# Epoch: 38 mini-batch: 1001  train-loss: 1.96544
# Epoch: 38 mini-batch: 1201  train-loss: 2.01153
# Epoch: 38 mini-batch: 1401  train-loss: 1.99071
# Epoch: 38 mini-batch: 1601  train-loss: 2.00856
# Epoch: 38 mini-batch: 1801  train-loss: 2.03153
# Epoch: 38 mini-batch: 2001  train-loss: 2.01919
# Epoch: 38 mini-batch: 2201  train-loss: 2.00638
# Epoch: 38 mini-batch: 2401  train-loss: 1.96714
# Epoch: 38  mean-valid-loss 1.94055
# Epoch: 39 mini-batch: 1  train-loss: 2.01768
# Epoch: 39 mini-batch: 201  train-loss: 2.03481
# Epoch: 39 mini-batch: 401  train-loss: 2.00021
# Epoch: 39 mini-batch: 601  train-loss: 2.01273
# Epoch: 39 mini-batch: 801  train-loss: 1.99541
# Epoch: 39 mini-batch: 1001  train-loss: 1.96545
# Epoch: 39 mini-batch: 1201  train-loss: 2.01155
# Epoch: 39 mini-batch: 1401  train-loss: 1.99064
# Epoch: 39 mini-batch: 1601  train-loss: 2.00856
# Epoch: 39 mini-batch: 1801  train-loss: 2.03151
# Epoch: 39 mini-batch: 2001  train-loss: 2.01903
# Epoch: 39 mini-batch: 2201  train-loss: 2.00635
# Epoch: 39 mini-batch: 2401  train-loss: 1.96706
# Epoch: 39  mean-valid-loss 1.94055
# Epoch: 40 mini-batch: 1  train-loss: 2.01769
# Epoch: 40 mini-batch: 201  train-loss: 2.03481
# Epoch: 40 mini-batch: 401  train-loss: 2.00016
# Epoch: 40 mini-batch: 601  train-loss: 2.01274
# Epoch: 40 mini-batch: 801  train-loss: 1.99551
# Epoch: 40 mini-batch: 1001  train-loss: 1.96538
# Epoch: 40 mini-batch: 1201  train-loss: 2.01151
# Epoch: 40 mini-batch: 1401  train-loss: 1.99074
# Epoch: 40 mini-batch: 1601  train-loss: 2.00855
# Epoch: 40 mini-batch: 1801  train-loss: 2.03151
# Epoch: 40 mini-batch: 2001  train-loss: 2.01910
# Epoch: 40 mini-batch: 2201  train-loss: 2.00623
# Epoch: 40 mini-batch: 2401  train-loss: 1.96707
# Epoch: 40  mean-valid-loss 1.94055
# Epoch: 41 mini-batch: 1  train-loss: 2.01768
# Epoch: 41 mini-batch: 201  train-loss: 2.03482
# Epoch: 41 mini-batch: 401  train-loss: 2.00014
# Epoch: 41 mini-batch: 601  train-loss: 2.01274
# Epoch: 41 mini-batch: 801  train-loss: 1.99544
# Epoch: 41 mini-batch: 1001  train-loss: 1.96545
# Epoch: 41 mini-batch: 1201  train-loss: 2.01153
# Epoch: 41 mini-batch: 1401  train-loss: 1.99073
# Epoch: 41 mini-batch: 1601  train-loss: 2.00857
# Epoch: 41 mini-batch: 1801  train-loss: 2.03150
# Epoch: 41 mini-batch: 2001  train-loss: 2.01917
# Epoch: 41 mini-batch: 2201  train-loss: 2.00650
# Epoch: 41 mini-batch: 2401  train-loss: 1.96709
# Epoch: 41  mean-valid-loss 1.94055
# Epoch: 42 mini-batch: 1  train-loss: 2.01763
# Epoch: 42 mini-batch: 201  train-loss: 2.03479
# Epoch: 42 mini-batch: 401  train-loss: 2.00023
# Epoch: 42 mini-batch: 601  train-loss: 2.01270
# Epoch: 42 mini-batch: 801  train-loss: 1.99543
# Epoch: 42 mini-batch: 1001  train-loss: 1.96541
# Epoch: 42 mini-batch: 1201  train-loss: 2.01154
# Epoch: 42 mini-batch: 1401  train-loss: 1.99072
# Epoch: 42 mini-batch: 1601  train-loss: 2.00855
# Epoch: 42 mini-batch: 1801  train-loss: 2.03147
# Epoch: 42 mini-batch: 2001  train-loss: 2.01902
# Epoch: 42 mini-batch: 2201  train-loss: 2.00642
# Epoch: 42 mini-batch: 2401  train-loss: 1.96710
# Epoch: 42  mean-valid-loss 1.94056
# Epoch: 43 mini-batch: 1  train-loss: 2.01767
# Epoch: 43 mini-batch: 201  train-loss: 2.03478
# Epoch: 43 mini-batch: 401  train-loss: 2.00019
# Epoch: 43 mini-batch: 601  train-loss: 2.01273
# Epoch: 43 mini-batch: 801  train-loss: 1.99545
# Epoch: 43 mini-batch: 1001  train-loss: 1.96544
# Epoch: 43 mini-batch: 1201  train-loss: 2.01144
# Epoch: 43 mini-batch: 1401  train-loss: 1.99073
# Epoch: 43 mini-batch: 1601  train-loss: 2.00855
# Epoch: 43 mini-batch: 1801  train-loss: 2.03155
# Epoch: 43 mini-batch: 2001  train-loss: 2.01906
# Epoch: 43 mini-batch: 2201  train-loss: 2.00639
# Epoch: 43 mini-batch: 2401  train-loss: 1.96706
# Epoch: 43  mean-valid-loss 1.94055
# Epoch: 44 mini-batch: 1  train-loss: 2.01767
# Epoch: 44 mini-batch: 201  train-loss: 2.03475
# Epoch: 44 mini-batch: 401  train-loss: 2.00027
# Epoch: 44 mini-batch: 601  train-loss: 2.01269
# Epoch: 44 mini-batch: 801  train-loss: 1.99545
# Epoch: 44 mini-batch: 1001  train-loss: 1.96544
# Epoch: 44 mini-batch: 1201  train-loss: 2.01149
# Epoch: 44 mini-batch: 1401  train-loss: 1.99077
# Epoch: 44 mini-batch: 1601  train-loss: 2.00855
# Epoch: 44 mini-batch: 1801  train-loss: 2.03148
# Epoch: 44 mini-batch: 2001  train-loss: 2.01905
# Epoch: 44 mini-batch: 2201  train-loss: 2.00648
# Epoch: 44 mini-batch: 2401  train-loss: 1.96706
# Epoch: 44  mean-valid-loss 1.94056
# Epoch: 45 mini-batch: 1  train-loss: 2.01770
# Epoch: 45 mini-batch: 201  train-loss: 2.03476
# Epoch: 45 mini-batch: 401  train-loss: 2.00028
# Epoch: 45 mini-batch: 601  train-loss: 2.01274
# Epoch: 45 mini-batch: 801  train-loss: 1.99544
# Epoch: 45 mini-batch: 1001  train-loss: 1.96545
# Epoch: 45 mini-batch: 1201  train-loss: 2.01159
# Epoch: 45 mini-batch: 1401  train-loss: 1.99076
# Epoch: 45 mini-batch: 1601  train-loss: 2.00852
# Epoch: 45 mini-batch: 1801  train-loss: 2.03147
# Epoch: 45 mini-batch: 2001  train-loss: 2.01905
# Epoch: 45 mini-batch: 2201  train-loss: 2.00644
# Epoch: 45 mini-batch: 2401  train-loss: 1.96712
# Epoch: 45  mean-valid-loss 1.94056
# Epoch: 46 mini-batch: 1  train-loss: 2.01763
# Epoch: 46 mini-batch: 201  train-loss: 2.03478
# Epoch: 46 mini-batch: 401  train-loss: 2.00027
# Epoch: 46 mini-batch: 601  train-loss: 2.01274
# Epoch: 46 mini-batch: 801  train-loss: 1.99542
# Epoch: 46 mini-batch: 1001  train-loss: 1.96543
# Epoch: 46 mini-batch: 1201  train-loss: 2.01150
# Epoch: 46 mini-batch: 1401  train-loss: 1.99064
# Epoch: 46 mini-batch: 1601  train-loss: 2.00855
# Epoch: 46 mini-batch: 1801  train-loss: 2.03150
# Epoch: 46 mini-batch: 2001  train-loss: 2.01911
# Epoch: 46 mini-batch: 2201  train-loss: 2.00639
# Epoch: 46 mini-batch: 2401  train-loss: 1.96707
# Epoch: 46  mean-valid-loss 1.94056
# Epoch: 47 mini-batch: 1  train-loss: 2.01768
# Epoch: 47 mini-batch: 201  train-loss: 2.03476
# Epoch: 47 mini-batch: 401  train-loss: 2.00014
# Epoch: 47 mini-batch: 601  train-loss: 2.01268
# Epoch: 47 mini-batch: 801  train-loss: 1.99542
# Epoch: 47 mini-batch: 1001  train-loss: 1.96545
# Epoch: 47 mini-batch: 1201  train-loss: 2.01150
# Epoch: 47 mini-batch: 1401  train-loss: 1.99070
# Epoch: 47 mini-batch: 1601  train-loss: 2.00852
# Epoch: 47 mini-batch: 1801  train-loss: 2.03149
# Epoch: 47 mini-batch: 2001  train-loss: 2.01912
# Epoch: 47 mini-batch: 2201  train-loss: 2.00623
# Epoch: 47 mini-batch: 2401  train-loss: 1.96701
# Epoch: 47  mean-valid-loss 1.94056
# Epoch: 48 mini-batch: 1  train-loss: 2.01772
# Epoch: 48 mini-batch: 201  train-loss: 2.03479
# Epoch: 48 mini-batch: 401  train-loss: 2.00018
# Epoch: 48 mini-batch: 601  train-loss: 2.01276
# Epoch: 48 mini-batch: 801  train-loss: 1.99543
# Epoch: 48 mini-batch: 1001  train-loss: 1.96544
# Epoch: 48 mini-batch: 1201  train-loss: 2.01156
# Epoch: 48 mini-batch: 1401  train-loss: 1.99073
# Epoch: 48 mini-batch: 1601  train-loss: 2.00856
# Epoch: 48 mini-batch: 1801  train-loss: 2.03149
# Epoch: 48 mini-batch: 2001  train-loss: 2.01912
# Epoch: 48 mini-batch: 2201  train-loss: 2.00646
# Epoch: 48 mini-batch: 2401  train-loss: 1.96709
# Epoch: 48  mean-valid-loss 1.94056
# Epoch: 49 mini-batch: 1  train-loss: 2.01764
# Epoch: 49 mini-batch: 201  train-loss: 2.03476
# Epoch: 49 mini-batch: 401  train-loss: 2.00009
# Epoch: 49 mini-batch: 601  train-loss: 2.01273
# Epoch: 49 mini-batch: 801  train-loss: 1.99544
# Epoch: 49 mini-batch: 1001  train-loss: 1.96542
# Epoch: 49 mini-batch: 1201  train-loss: 2.01153
# Epoch: 49 mini-batch: 1401  train-loss: 1.99072
# Epoch: 49 mini-batch: 1601  train-loss: 2.00853
# Epoch: 49 mini-batch: 1801  train-loss: 2.03149
# Epoch: 49 mini-batch: 2001  train-loss: 2.01911
# Epoch: 49 mini-batch: 2201  train-loss: 2.00646
# Epoch: 49 mini-batch: 2401  train-loss: 1.96709
# Epoch: 49  mean-valid-loss 1.94056
# ===> Saving models...
# ===> Saving model finished...
# tensor(0.3324, device='cuda:0', dtype=torch.float64) ++++++++++++++++++++++++++++++++
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:121: UserWarning: In Matplotlib 3.3 individual lines on a stem plot will be added as a LineCollection instead of individual lines. This significantly improves the performance of a stem plot. To remove this warning and switch to the new behaviour, set the "use_line_collection" keyword argument to True.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:129: UserWarning: In Matplotlib 3.3 individual lines on a stem plot will be added as a LineCollection instead of individual lines. This significantly improves the performance of a stem plot. To remove this warning and switch to the new behaviour, set the "use_line_collection" keyword argument to True.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:121: UserWarning: In Matplotlib 3.3 individual lines on a stem plot will be added as a LineCollection instead of individual lines. This significantly improves the performance of a stem plot. To remove this warning and switch to the new behaviour, set the "use_line_collection" keyword argument to True.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:129: UserWarning: In Matplotlib 3.3 individual lines on a stem plot will be added as a LineCollection instead of individual lines. This significantly improves the performance of a stem plot. To remove this warning and switch to the new behaviour, set the "use_line_collection" keyword argument to True.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:121: UserWarning: In Matplotlib 3.3 individual lines on a stem plot will be added as a LineCollection instead of individual lines. This significantly improves the performance of a stem plot. To remove this warning and switch to the new behaviour, set the "use_line_collection" keyword argument to True.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:129: UserWarning: In Matplotlib 3.3 individual lines on a stem plot will be added as a LineCollection instead of individual lines. This significantly improves the performance of a stem plot. To remove this warning and switch to the new behaviour, set the "use_line_collection" keyword argument to True.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:121: UserWarning: In Matplotlib 3.3 individual lines on a stem plot will be added as a LineCollection instead of individual lines. This significantly improves the performance of a stem plot. To remove this warning and switch to the new behaviour, set the "use_line_collection" keyword argument to True.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:129: UserWarning: In Matplotlib 3.3 individual lines on a stem plot will be added as a LineCollection instead of individual lines. This significantly improves the performance of a stem plot. To remove this warning and switch to the new behaviour, set the "use_line_collection" keyword argument to True.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:121: UserWarning: In Matplotlib 3.3 individual lines on a stem plot will be added as a LineCollection instead of individual lines. This significantly improves the performance of a stem plot. To remove this warning and switch to the new behaviour, set the "use_line_collection" keyword argument to True.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:129: UserWarning: In Matplotlib 3.3 individual lines on a stem plot will be added as a LineCollection instead of individual lines. This significantly improves the performance of a stem plot. To remove this warning and switch to the new behaviour, set the "use_line_collection" keyword argument to True.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:121: UserWarning: In Matplotlib 3.3 individual lines on a stem plot will be added as a LineCollection instead of individual lines. This significantly improves the performance of a stem plot. To remove this warning and switch to the new behaviour, set the "use_line_collection" keyword argument to True.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:129: UserWarning: In Matplotlib 3.3 individual lines on a stem plot will be added as a LineCollection instead of individual lines. This significantly improves the performance of a stem plot. To remove this warning and switch to the new behaviour, set the "use_line_collection" keyword argument to True.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:121: UserWarning: In Matplotlib 3.3 individual lines on a stem plot will be added as a LineCollection instead of individual lines. This significantly improves the performance of a stem plot. To remove this warning and switch to the new behaviour, set the "use_line_collection" keyword argument to True.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:129: UserWarning: In Matplotlib 3.3 individual lines on a stem plot will be added as a LineCollection instead of individual lines. This significantly improves the performance of a stem plot. To remove this warning and switch to the new behaviour, set the "use_line_collection" keyword argument to True.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:121: UserWarning: In Matplotlib 3.3 individual lines on a stem plot will be added as a LineCollection instead of individual lines. This significantly improves the performance of a stem plot. To remove this warning and switch to the new behaviour, set the "use_line_collection" keyword argument to True.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:129: UserWarning: In Matplotlib 3.3 individual lines on a stem plot will be added as a LineCollection instead of individual lines. This significantly improves the performance of a stem plot. To remove this warning and switch to the new behaviour, set the "use_line_collection" keyword argument to True.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:121: UserWarning: In Matplotlib 3.3 individual lines on a stem plot will be added as a LineCollection instead of individual lines. This significantly improves the performance of a stem plot. To remove this warning and switch to the new behaviour, set the "use_line_collection" keyword argument to True.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:129: UserWarning: In Matplotlib 3.3 individual lines on a stem plot will be added as a LineCollection instead of individual lines. This significantly improves the performance of a stem plot. To remove this warning and switch to the new behaviour, set the "use_line_collection" keyword argument to True.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:121: UserWarning: In Matplotlib 3.3 individual lines on a stem plot will be added as a LineCollection instead of individual lines. This significantly improves the performance of a stem plot. To remove this warning and switch to the new behaviour, set the "use_line_collection" keyword argument to True.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:129: UserWarning: In Matplotlib 3.3 individual lines on a stem plot will be added as a LineCollection instead of individual lines. This significantly improves the performance of a stem plot. To remove this warning and switch to the new behaviour, set the "use_line_collection" keyword argument to True.
